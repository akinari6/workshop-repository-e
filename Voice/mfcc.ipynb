# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#! pip install librosa

# %%
import librosa

# %%
data, f = librosa.load("data/tsujita_a.mp3")
data2, f2 = librosa.load("data/kimura_a.mp3")

# %%
mfcc=librosa.feature.mfcc(data)
mfcc2 = librosa.feature.mfcc(data2)

# %%
data
# Out:
# array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#         1.6313045e-07, -2.2530827e-05,  0.0000000e+00], dtype=float32)

# %%
len(data)
# Out:
# 683021

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
data.shape
# Out:
# (683021,)

# %%
f
# Out:
# 22050

# %%
mfcc
# Out:
# array([[-420.6435    , -190.7512    , -160.51668   , ..., -486.9065    ,
#         -492.49072   , -503.14066   ],
#        [ 109.65866   ,  150.53757   ,  155.0936    , ...,   82.09167   ,
#           75.623276  ,   68.59688   ],
#        [   6.881531  ,  -26.10442   ,  -29.59976   , ...,   22.04076   ,
#           18.191843  ,   16.345537  ],
#        ...,
#        [   1.3061293 ,   -2.73414   ,   -3.4607155 , ...,    2.2369266 ,
#            0.7428893 ,    5.8641176 ],
#        [   1.543027  ,    2.0379844 ,    2.964573  , ...,   -2.552002  ,
#           -3.1394477 ,    1.3266913 ],
#        [   0.979843  ,    1.1505724 ,    0.98164606, ...,   -7.8721747 ,
#           -6.7829494 ,   -1.8768147 ]], dtype=float32)

# %%
from librosa import display

# %%
plt.figure(figsize=(16,9))
librosa.display.waveplot(data, f)
plt.show()

# %%
mfcc.shape
# Out:
# (20, 1335)

# %%
mfcc2.shape
# Out:
# (20, 1258)
